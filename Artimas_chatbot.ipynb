# %%
# !pip install chatterbot==1.0.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.5/515.5 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 30.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp39-cp39-linux_x86_64.whl size=1157821 sha256=f2707c02383820b077418672848b224ed39a95806ad146be8b1003074e3856d1
# ...

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
from chatterbot.trainers import ChatterBotCorpusTrainer

# %%
from chatterbot.logic import logic_adapter
from chatterbot.storage.sql_storage import SQLStorageAdapter
from chatterbot.storage import storage_adapter
chatbot1 = ChatBot('ARTIMAS',
                  storage_adapter='chatterbot.storage.SQLStorageAdapter'
                  )


trainer = ListTrainer(chatbot1)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
trainer.train(
    [
        "What is Artimas ?",
        "Artimas is an flagship event hosted by AiMSA .This flagship event is going tp happen in four days in hybrid mode ."
    ]
)

trainer.train(
    [
        "Describe AiMSA",
        "AiMSA is Artificial Intelligence and Machine Learning Students'' Association . It is students'' association of CSE(AI & ML)department in Pimpri Chinchwad College of Engineering,Pune."
    ]
)

trainer.train(
    [
        "Events hosted by AiMSA",
        "AiMSA had hosted BUILD YOUR OWN WEBSITE event for all admin staffs and now Artimas the flagship event is going on . This flagship event is going tp happen in four days in hybrid mode "
    ]
)

trainer.train(
    [
        "Who is the President of AiMSA ?",
        "Atharva Joshi is President of AiMSA."
    ]
)

trainer.train(
    [
        "Who is Vice President of AiMSA ?",
        "Parth Singhal is Vice-President of AiMSA."
    ]
)

trainer.train(
    [
        "Who is Secretary of AiMSA ?",
        "Lokesh Kad and Soham Narsale are secrataries of AiMSA"
    ]
)

trainer.train(
    [
        "Who is treasurer of AiMSA ?",
        "Shubham Singh and Vaibhav Gangurde are treasurers of AiMSA"
    ]
)

trainer.train(
    [
        "Who is Social Media Head of AiMSA ?",
        "Anurag Mishra and Harshal Nikalje are Social Media Heads of AiMSA"
    ]
)

trainer.train(
    [
        "Who is Marketing and Sponsorship Head of AiMSA ?",
        "Aarya Hire and Jivan Karande are Marketing and Sponsorship Heads of AiMSA"
    ]
)

trainer.train(
    [
        "Who is Webmaster of AiMSA ?",
        "Prathmesh Kolekar and Parth Halwane are webmasters of AiMSA"
    ]
)

trainer.train(
    [
        "Who is HoD of CSE(AIML) Department ?",
        "Dr. Anuradha Thakare is HoD of CSE (AIML) Department in PCCOE"
    ]
)

trainer.train(
    [
        "What is HackMatrix",
        "HackMatrix is an event happening under Artimas 2023 . It is a hackathon where participants have to build an AI chatbot aiming to Artimas ."
    ]
)

trainer.train(
    [
        "What is AiMSA ?",
        "AiMSA is Artificial Intelligence and Machine Learning Students'' Association . It is students'' association of CSE(AI & ML)department in Pimpri Chinchwad College of Engineering,Pune."
    ]
)

trainer.train(
    [
        "What is prizepool of Artimas 2023 ?",
        "Overall total prizepool of ARTIMAS 2023 is of Rs 35000."
    ]
)

trainer.train(
    [
        "Which which events are happening under Artimas 2023 ?",
        "There are 6 events namely : 1>Houdini Heist 2>Neurodrain 3>HackMatrix 4>Adrenaline Rush 5>Cybernetic Vision 6>Pixel Perfect"
    ]
)

trainer.train(
    [
        'Body Members of AiMSA ',
        "Body Members of AiMSA are as :  "
        "President : Atharva Joshi  "
        "Vice President : Parth Singhal  "
        "Secratary : Lokesh Kad and Soham Narsale  "
        "Treasurer : Shubham Singh and Vaibhav Gangurde  "
        "Social Media Head : Anurag Mishra and Harshal Nikalje  "
        "Design Head : Tushar Garad and Om Bhavsar  "
        "Marketing and Sponsorship Head : Aarya Hire and Jivan Karande  "
        "Web Master : Prathamesh Kolekar and Parth Halwane  "
        "Managing Professional Body chairperson : Parth Chitale  "
    ]
)

trainer.train(
    [
        "Number of rounds in Houdini Heist ",
        "There are 3 rounds in Houdini Hesit"
    ]
)

trainer.train(
    [
        "Number of rounds in Adrenaline Rush ",
        "There are 2 rounds in Adrenaline Rush"
    ]
)

trainer.train(
    [
        "Number of rounds in Cybernetic Vision ",
        "There are 2 rounds in Houdini Hesit"
    ]
)

trainer.train(
    [
        "Number of rounds in Pixel Perfect",
        "There is only one round in Pixel Perfect"
    ]
)

trainer.train(
    [
        "Number of rounds in NeuroDrain ",
        "There are 2 rounds in NeuroDrain"
    ]
)

trainer.train(
    [
        "Partcipation type in Houdini Heist ",
        "Houdini Hesit is a team event ",
        "What is prize of Houdini Heist ",
        "Prize of Houdini Heist is Rs 8000",
        "Contact details for Houdini Heist ",
        "Contact details for Houdini Heist are : Event Co-ordinator : Parth Singhal , Piyush Agrawal -> 7972103836 , Shubham Singh -> 7020989258 "
    ]
)

trainer.train(
    [
        "Partcipation type in Hack Matrix ",
        "Hack Matrix is a team event ",
        "What us prize of Hack Matrix",
        "Prize of Hack Matrix is Rs 7500",
        "Contact details for Hack Matrix ",
        "Contact details for Hack Matrix are : Event Co-ordinator : Atharva Joshi , Prathamesh Kolekar -> 8600713374 , Parth Halwane -> 9699528221 "
    ]
)

trainer.train(
    [
        "Partcipation type in Adrenaline Rush ",
        "Adrenaline Rush is a team event ",
        "Prize of Adrenaline Rush",
        "Prize of Adrenaline Rush is Rs 7500",
        "Contact details for Adrenaline Rush ",
        "Contact details for Adrenaline Rush are : Event Co-ordinator : Lokesh Kad , Ayush Dongardive -> 7559268257 , Kartik Jagtap -> 9175078113 "
    ]
)

trainer.train(
    [
        "Partcipation type in Cybernetic Vision ",
        "Cybernetic Vision is an individual event ",
        "Prize of Cybernetic Vision",
        "Prize of Cybernetic Vision is Rs 2000",
        "Provide me with the contact details of the organizers for the Cybernetic Visions event under Artimas ? ",
        "Contact details for Cybernetic Vision are : Om Bhavsar -> 9359560116 , Tushar Garad -> 9579121092 "
    ]
)

trainer.train(
    [
        "Partcipation type in Pixel Perfect",
        "Pixel Perfect is an individual event ",
        "Prize of Pixel Perfect ",
        "Prize of Pixel Perfect is Rs 2000",
        "Contact details for Pixel Perfect ",
        "Contact details for Pixel Perfect are : Harshad Gholve -> 7796198948 , Tushar Mahajan -> 7666100610 , Anurag Karpe -> 8805318256 "
    ]
)

trainer.train(
    [
        "Partcipation type in NeuroDrain ",
        "NeuroDrain is an individual event ",
        "Prize of NeuroDrain",
        "Prize of NeuroDrain is Rs 4000",
        "Contact details for NeuroDrain ",
        "Contact details for NeuroDrain are : Event Co-ordinator : Soham Narsale , Gautam Bhagat -> 9970102190 , Sayali Jadhao -> 9511293443 "
    ]
)


trainer.train(
    [
        "Who are the sponsors of Artimas ?",
        "SPOSNORS of ARTIMAS 2023 are : 1>SP KATTA 2>LOCA CAFE AND RESTAURANT 3>INTRA fitness club 4>MAHARASHTRA tyre house "
    ]
)


trainer.train(
    [
        'Team Members of AiMSA ',
        "Body Members of AiMSA are as :  "
        "President : Atharva Joshi  "
        "Vice President : Parth Singhal  "
        "Secratary : Lokesh Kad and Soham Narsale  "
        "Treasurer : Shubham Singh and Vaibhav Gangurde  "
        "Social Media Head : Anurag Mishra and Harshal Nikalje  "
        "Design Head : Tushar Garad and Om Bhavsar  "
        "Marketing and Sponsorship Head : Aarya Hire and Jivan Karande  "
        "Web Master : Prathamesh Kolekar and Parth Halwane  "
        "Managing Professional Body chairperson : Parth Chitale  "
    ]
)

trainer.train(
    [
        "Who is SDW Co-ordinator ?",
        "SDW Co-ordinator is Prof Pallavi Dhade"
    ]
)

trainer.train(
    [
        "What are time constraints for Houdini Heist",
        "Round 1 will be held for 20 minutes with 15 questions"
        "Then second round will also be held for 20 minutes but with 10 questions"
        "And the final round round 3 will be held for 1 hour"
    ]
)

trainer.train(
    [
        "What are time constraints for NeuroDrain",
        "Round 1 will be held for 40 minutes"
        "Then second round will be held for 60 minutes that is 1 hour"
    ]
)

trainer.train(
    [
        "What are time constraints for PixelPerfect",
        "Pixel Perfect will be held from morning 9:00 am to night 9:00 pm"
    ]
)

trainer.train(
    [
        "What are time constraints for CyberNetic Vision",
        "First round is that you have to submit the posters till 16th of April 12 noon"
        "Then second round will be held for 60 minutes that is 1 hour on 17th of April"
    ]
)

trainer.train(
    [
        "What are time constraints for Adrenaline Rush",
        "First round will be held on 16th of April from 9:00 am to 6:00 pm"
        "Then second round will be held from 12:00 pm to 2:00 pm on 18th of April"
    ]
)

trainer.train(
    [
        "What are time constraints for HackMatrix",
        "First round will be held on 15th of April from 9:00 am to 9:00 pm online"
        "Then second round will be held from 09:00 am to 12:00 pm on 17th of April for 3 hours"
    ]
)

trainer.train(
    [
        "What are constraints/conditions/rules for Houdini Heist ",
        "Team participation: Only teams of 3 people will be considered. "
        "TOP 15 TEAMS WILL PROCEED TO THE second ROUND who qualified first round of quiz. "
        "Then TOP 3 TEAMS  QUALIFYING ROUND 2 WILL PROCEED TO THE FINAL ROUND. "
        "First 2 teams to escape win. "

    ]
)

trainer.train(
    [
        "What is judging criteria of Houdini Heist",
        "Teams will be assessed based on the number of questions answered correctly in first round . "
        "In round 2 , First team to answer the question correctly gets a point and if multiple teams  "
        "answer correctly at the same time then all of them will get a point. "
        "The final 3 teams will be playing the game in 3 different rooms. "
        "First 2 teams to escape win. "
    ]
)

trainer.train(
    [
        "What are constraints/conditions/rules for HackMatrix ",
        "Team participation: Only teams of 3 people will be considered. "
        "TOP 15 TEAMS WILL PROCEED TO THE second ROUND who qualified first round of quiz. "
        "Then TOP 3 TEAMS  QUALIFYING ROUND 2 WILL PROCEED TO THE FINAL ROUND. "
        "First 2 teams to escape win. "

    ]
)

trainer.train(
    [
      "What are judging criteria for HackMatrix ",
     "For loading screen of Artimas logo , evaluation will be done on basis of working and creativity,respictively 15 and 10 points for working and creativity. "
     "For Artimas chatbot evaluation will be done based on correctness of answer . "
     "Questions having difficulty level 1 will have 5 points where as questions with difficulty level 2 has 10 points ."
    ]
)

trainer.train(
    [
        "Constraints/Conditions/rules for NeuroDrain ",
        "ROUND 1 will be  Logical Aptitude Test"
        "TOP 15 STUDENTS WILL BE SHORTLISTED FOR ROUND 2"
        "Round 2 will be technical quiz "
        "1)Teams will be allotted by the Quizmaster on the spot. "
        "2) Each team will be sharing one buzzer. "
        "3) Teams will consist of 3 members each. "
        "4) Misusing the buzzer will result in termination of the entire team."
    ]
)

trainer.train(
    [
        "Judging criteria for NeuroDrain ",
        "Judging Criteria will be : "
        "1. Submission time "
        "2. Correct Answer "
    ]
)

trainer.train(
    [
        "Constraints/conditions/rules for Pixel Perfect",
        "All photos should be clicked within the campus. "
        "5. The photo clicked should be during the time of ARTIMAS (Time-stamp required). "
        "6. Only one submission is allowed per participant. "
        "Normal editing will be allowed but photoshopping is not allowed. "
        "10. Photo should not contain any type of watermark "
        "11. Participants should submit the original image along with the edited image (if the "
        "image is edited). "
        "The organizers reserve the right to disqualify any participant who fails to comply with "
        "the rules or provides false information."
    ]
)

trainer.train(
    [
        "Tell me the judging criteria for Pixel Perfect.",
        "Winner will be selected based on creativity, composition, and uniqueness."
    ]
)

trainer.train(
    [
        "Constraints/conditions/rules for Cybernetic vision ",
        "Only registered candidates are considered. "
        "Final poster should be submitted in png format only. "
        "Specifications given at the starting of round should be followed. "
        "No templates should be used. "
    ]
)

trainer.train(
    [
        "Judging criteria for Cybernetic Vision ",
        "Points for evaluations : 1>Creativity and originality 2>Visual Impact 3>Message Clearity 4>Technical skills 5>Relevance to theme 6>Overall Impression "
    ]
)

trainer.train(
    [
        "Constarints/conditions/rules for Adrenaline Rush ",
        "1. Each team must include five members. "
        "2. The tournament will be played in a knock-out format. "
        "3. The tournament will use the standard competitive game settings. "
        "4. There will be 2 rounds: Round 1 to be held on 16th March 23 (Online mode), Round 2 "
        "(Final/Semi-final) to be held on 18th March 23 (Venue: 5205LAB). "
        "5. The map allocation will be done by the organizers. "
        "6. Each match will have a designated observer to oversee the game. "
        "7. Any use of cheats or exploits will result in disqualification. "
        "8. Each player must have a valid valorant account and should use their official name throughout the tournament. "
        "9. Players are expected to join the room created by the organizers 15 mins prior to the "
        "match, any delay by the team to start the match will result in a forfeit. "
        "10. The team leader is responsible for inviting all team members to join the room. 11. "
        "Participants must bring their own devices to play in offline mode. Only LAN cable "
        "(Internet Access) and power supply will be provided. "
        "12. Each team should play with the same squad which is registered. No changes will be "
        "considered in the team formation after the registration. "
        "13. If a player is found playing in more than one team, the entire team will be "
        "disqualified. "
        "14. In case of a disconnection, the match will be paused for maximum 5 mins and allowed "
        "to reconnect, if failed to do so the team will have to forfeit the match. "
        "15. Any disputes or complaints must be reported to the tournament "
        "organizers immediately. "
        "16. Players are expected to behave appropriately and respectfully towards other "
        "players. 17. Any violation of the rules will be dealt with accordingly. "
        "18. Referees/Organizers decisions will be final and to be followed accordingly."
    ]
)

trainer.train(
    [
        "Judging criteria for Adrenaline Rush ",
        "Winner team in the game in final round will be the winner team of event."
    ]
)

from chatterbot.trainers import ChatterBotCorpusTrainer

trainercorpus = ChatterBotCorpusTrainer(chatbot1)

trainercorpus.train('chatterbot.corpus.english')
# Out:
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# ...

# %%
print("ARTIMAS : Hello,welcome to ARTIMAS ")
while True:
  try :
    ques = input('Ask your question : ')
    if(ques == 'Exit' or ques == 'exit'):
      print("ARTIMAS : Thank You !")
      break
    bot_input = chatbot1.get_response(ques)
    print('ARTIMAS : ',bot_input)

  except(KeyboardInterrupt,EOFError,SystemExit) :
    break
# Out:
# ARTIMAS : Hello,welcome to ARTIMAS
# ARTIMAS :  Hi
# ARTIMAS :  I am on the Internet.
# ARTIMAS :  Points for evaluations : 1>Creativity and originality 2>Visual Impact 3>Message Clearity 4>Technical skills 5>Relevance to theme 6>Overall Impression
# ARTIMAS :  what is venus
# ARTIMAS :  Body Members of AiMSA
# ARTIMAS :  AiMSA is Artificial Intelligence and Machine Learning Students'' Association . It is students'' association of CSE(AI & ML)department in Pimpri Chinchwad College of Engineering,Pune.
# ARTIMAS :  Contact details for NeuroDrain are : Event Co-ordinator : Soham Narsale , Gautam Bhagat -> 9970102190 , Sayali Jadhao -> 9511293443
# ARTIMAS :  I dream that I will become rich.
# ARTIMAS :  My software runs on all operating systems including Windows, Linux and Mac OS.
# ARTIMAS :  Dr. Anuradha Thakare is HoD of CSE (AIML) Department in PCCOE
# ARTIMAS :  what is the stock market
# ARTIMAS :  There are 3 rounds in Houdini Hesit
# ...
